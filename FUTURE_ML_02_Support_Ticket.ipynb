# %%
import pandas as pd

data = {
    'Ticket':[
        'Internet not working',
        'Password reset issue',
        'Computer is slow',
        'Email login problem',
        'Printer not working'
    ],

    'Category':[
        'Network',
        'Account',
        'Hardware',
        'Account',
        'Hardware'
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#                  Ticket  Category
# 0  Internet not working   Network
# 1  Password reset issue   Account
# 2      Computer is slow  Hardware
# 3   Email login problem   Account
# 4   Printer not working  Hardware

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Convert text into numbers
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['Ticket'])

# Train model
model = MultinomialNB()
model.fit(X, df['Category'])

print("Model Training Complete!")
# Out:
# Model Training Complete!

# %%
new_ticket = ["Wifi connection problem"]

new_data = vectorizer.transform(new_ticket)

prediction = model.predict(new_data)

print("Predicted Category =", prediction[0])
# Out:
# Predicted Category = Account

# %%
import pandas as pd

data = {
'Ticket':[
'Internet not working',
'Wifi issue',
'Network connection failed',
'Password reset issue',
'Email login problem',
'Forgot password',
'Computer is slow',
'Printer not working',
'Laptop overheating'
],

'Category':[
'Network',
'Network',
'Network',
'Account',
'Account',
'Account',
'Hardware',
'Hardware',
'Hardware'
]
}

df = pd.DataFrame(data)

print(df)
# Out:
#                       Ticket  Category
# 0       Internet not working   Network
# 1                 Wifi issue   Network
# 2  Network connection failed   Network
# 3       Password reset issue   Account
# 4        Email login problem   Account
# 5            Forgot password   Account
# 6           Computer is slow  Hardware
# 7        Printer not working  Hardware
# 8         Laptop overheating  Hardware

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(df['Ticket'])

model = MultinomialNB()

model.fit(X, df['Category'])

print("Model Training Complete!")
# Out:
# Model Training Complete!

# %%
new_ticket = ["Wifi connection problem"]

new_data = vectorizer.transform(new_ticket)

prediction = model.predict(new_data)

print("Predicted Category =", prediction[0])
# Out:
# Predicted Category = Network

# %% [markdown]
# # Support Ticket Classification Project
#
# This project classifies support tickets using Machine Learning.
#
# Tools Used:
# - Python
# - Pandas
# - Scikit-learn
#
# Steps:
# 1. Created support ticket dataset
# 2. Trained Machine Learning model
# 3. Classified support tickets
# 4. Predicted ticket category
#
# Output:
# Wifi connection problem → Network
